# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
customers = pd.read_excel('output.xlsx',
sheetname=1,
header=0,
index_col=False,
keep_default_na=True
)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/io/excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)

# %%
customers
# Out:
#      Month WeekOfMonth  DayOfWeek       Make AccidentArea DayOfWeekClaimed  \
# 6      Jan           5     Monday      Honda        Urban          Tuesday
# 7      Oct           4     Friday      Honda        Urban        Wednesday
# 8      Nov           1     Friday      Honda        Urban          Tuesday
# 9      Apr           3    Tuesday       Ford        Urban        Wednesday
# 10     Apr           4     Monday      Honda        Urban          Tuesday
# 11     Aug           3     Sunday      Mazda        Urban         Thursday
# 12     Jun           3   Saturday    Pontiac        Urban          Tuesday
# 13     Sep           3     Friday      Mazda        Urban           Friday
# 14     May           3     Sunday     Accura        Urban           Friday
# 15     Mar           1     Sunday      Honda        Urban          Tuesday
# 16     Jan           4    Tuesday       Ford        Urban        Wednesday
# ...

# %%
customers.drop(customers.index[0:5],inplace=True)

# %%
del customers['EXL EQ Case Challenge 2019']

# %%
column=customers.iloc[0].values
customers.columns=column
customers.drop(customers.index[0],inplace=True)

# %%
customers.to_csv('output_round1.cvs',index=False)

# %%
customers.shape
# Out:
# (3855, 34)
